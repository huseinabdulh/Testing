# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/How to add GITHUB
# Out:
# /content/drive/MyDrive/Colab Notebooks/How to add GITHUB

# %%
# !ls -a
# Out:
# colabGitWorkFlow.ipynb	.git  Reccomendation_learn.ipynb  Untitled0.ipynb

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/How to add GITHUB

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/How to add GITHUB/.git/

# %%
# !ls -a
# Out:
# colabGitWorkFlow.ipynb	Reccomendation_learn.ipynb  Untitled0.ipynb

# %%
# !git remote add origin https://huseinabdulh:huuseeiinn18@github.com/huseinabdulh/Recomendation_Learn.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://huseinabdulh:huuseeiinn18@github.com/huseinabdulh/Recomendation_Learn.git (fetch)
# origin	https://huseinabdulh:huuseeiinn18@github.com/huseinabdulh/Recomendation_Learn.git (push)

# %%
# !git config --global user.email 'huseinabdulh@gmail.com'
# !git config --global user.name 'huseinabdulh'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# error: short read while indexing colabGitWorkFlow.ipynb
# error: colabGitWorkFlow.ipynb: failed to insert into database
# error: unable to index file colabGitWorkFlow.ipynb
# fatal: adding files failed
# On branch master
#
# Initial commit
#
# Untracked files:
# 	Collaborative_filterring.ipynb
# 	Kaggle.txt
# 	Reccomendation_learn.ipynb
# 	Recomendation_based_content.ipynb
# 	Simpler_Recomender.ipynb
# 	colabGitWorkFlow.ipynb
# 	credits.csv
# 	kaggle.json
# 	keywords.csv
# 	links.csv
# 	links_small.csv
# 	model.png
# 	movies_metadata.csv
# 	ratings.csv
# 	ratings_small.csv
# 	the-movies-dataset.zip
#
# nothing added to commit but untracked files present

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://huseinabdulh:huuseeiinn18@github.com/huseinabdulh/Recomendation_Learn.git'
